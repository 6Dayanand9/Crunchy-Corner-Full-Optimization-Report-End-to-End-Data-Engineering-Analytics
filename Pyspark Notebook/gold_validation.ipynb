# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import pyspark.pandas as pd
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 3, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.

# %%
silver_actual=pd.read_delta("abfss://eb257234-8b24-4c02-8b7c-53b230c8bb1a@onelake.dfs.fabric.microsoft.com/fd0e410a-d046-4650-86ee-197dcd0650f1/Tables/dbo/silver_actual")
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 4, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_delta`, the default index is attached which can cause additional overhead.

# %%
silver_actual.head()
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 6, Finished, Available, Finished)
#    year quarter month    sku_code                                      sku_description    category sub_category     product sub_product cluster_head       channel location  volume_mt  gross_sales  discount  trade_spend  total_t_and_disc  net_revenue  raw_material  packging_material  industrial_fixed_cost  industrial_variable_cost  total_fixed_and_variable_cost    cogs  goss_profit   gp%  marketing  sandd  ganda  other_inc_and_exp  ebitda  depriciation  one_off_item  tax  interest_income  interest_exp  net_profit
# ...

# %%
gold_fact_actual = pd.read_delta("abfss://eb257234-8b24-4c02-8b7c-53b230c8bb1a@onelake.dfs.fabric.microsoft.com/fd0e410a-d046-4650-86ee-197dcd0650f1/Tables/dbo/gold_fact_actual")
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 7, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_delta`, the default index is attached which can cause additional overhead.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
gold_fact_actual.head()
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 8, Finished, Available, Finished)
#    product_key  Date_id  cluster_id  channel_id  location_id  volume_mt  gross_sales  discount  trade_spend  total_t_and_disc  net_revenue  raw_material  packging_material  industrial_fixed_cost  industrial_variable_cost  total_fixed_and_variable_cost     cogs  goss_profit   gp%  marketing  sandd  ganda  other_inc_and_exp   ebitda  depriciation  one_off_item  tax  interest_income  interest_exp  net_profit
# 0          618       12           6           0            6       0.05       277.77       0.0      -152.77           -152.77       125.00       -235.93                0.0                    0.0                   -421.85                        -421.85  -657.77      -532.77 -4.26       0.02  -9.21  -1.19                0.0  -543.15         -0.37         -0.18  0.0              0.0         -1.13     -544.83
# ...

# %%
print(silver_actual.shape)
print(gold_fact_actual.shape)
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 12, Finished, Available, Finished)
# (477872, 37)
# (477872, 30)

# %%
print("silver actual",silver_actual['gross_sales'].sum())
print("fact gold actual",gold_fact_actual['gross_sales'].sum())
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 20, Finished, Available, Finished)
# silver actual 673746327.1789787
# fact gold actual 673746327.1789917

# %%
print("silver net_revenue", silver_actual['net_revenue'].sum())
print("gold net_revenue", gold_fact_actual['net_revenue'].sum())

print("silver net_profit", silver_actual['net_profit'].sum())
print("gold net_profit", gold_fact_actual['net_profit'].sum())
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 21, Finished, Available, Finished)
# silver net_revenue 560069105.8152264
# gold net_revenue 560069105.8151819
# silver net_profit 61125383.38247627
# gold net_profit 61125383.382477

# %%
print("null product_key",
      gold_fact_actual['product_key'].isna().sum())

print("null channel_key",
      gold_fact_actual['channel_id'].isna().sum())

print("null date_id",
      gold_fact_actual['Date_id'].isna().sum())
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 25, Finished, Available, Finished)
# null product_key 0
# null channel_key 0
# null date_id 0

# %%
assert round(silver_actual['gross_sales'].sum()) == round(gold_fact_actual['gross_sales'].sum()), \
    "Gross sales mismatch!"

assert gold_fact_actual['product_key'].isna().sum() == 0, \
    "Null product_key found!"
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 28, Finished, Available, Finished)

# %%
print("silver actual",round(silver_actual['gross_sales'].sum()))
# Out:
# StatementMeta(, 3d1652cc-d5c8-4e37-b6c0-532345f7cb00, 27, Finished, Available, Finished)
# silver actual 673746327
